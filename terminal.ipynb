# %%
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import os
from google.colab import drive
from google.colab import auth
from google.auth import default

drive.mount('/content/drive')
# %cd /content/drive/MyDrive/workspace/normal_estimation
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/workspace/normal_estimation

# %%
# !pip install -r requirements.txt

# %%
# !mkdir -p datasets

# %%
# !pip install --upgrade huggingface_hub

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `dfd` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# ...

# %%
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py", line 409, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.11/dist-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/api/models/facebook/gelsight-force-estimation/revision/main
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/huggingface-cli", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/commands/huggingface_cli.py", line 57, in main
#     service.run()
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/commands/download.py", line 153, in run
# ...

# %%
# !pip install rospkg catkin_pkg defusedxml

# %%
# !python src/canfnet/scripts/train/train.py \
  --device cuda \
  --epochs 10 --batch-size 32 \
  --load models/DIGIT/model_24-02-2023_14-49-02_256_digit.pth \
  --old-ckpt models/DIGIT/model_24-02-2023_14-49-02_256_digit.pth \
  --lwf-lambda 1.0 \
  --force-max 3.0
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/workspace/normal_estimation/src/canfnet/scripts/train/train.py", line 24, in <module>
#     import neptune.new as neptune
# ModuleNotFoundError: No module named 'neptune'
